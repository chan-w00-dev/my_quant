# %%
a = "foo"

# %%
words = ["apple", "bat", "bar", "atom", "book"]

# %%
by_letter = {}

# %%
for word in words:
# Out:
#   Cell In[4], line 1
#     for word in words:
#                       ^
# SyntaxError: incomplete input

# %%
for word in words:
    letter = word[0]
    if letter not in by_letter:
        by_letter[letter] = [word]
    else:
        by_letter[letter].append(word)

# %%
by_letter
# Out:
# {'a': ['apple', 'atom'], 'b': ['bat', 'bar', 'book']}

# %%
from collections import defaultdict

# %%
by_letter = defaultdict(list)

# %%
by_letter
# Out:
# defaultdict(list, {})

# %%
for word in words:
    by_letter[word[0]].append(word)

# %%
by_letter
# Out:
# defaultdict(list, {'a': ['apple', 'atom'], 'b': ['bat', 'bar', 'book']})

# %%
collection = [1,2,3]

# %%
collection
# Out:
# [1, 2, 3]

# %%
index = 0

# %%
for value in collection:
    index += 1

# %%
index
# Out:
# 3

# %%
idx = 0

# %%
for idx, value in enumerate(collection):
    idx, value

# %%
idx , value
# Out:
# (2, 3)

# %%
a = []

# %%
for idx, value in enumerate(collection):
# Out:
#   Cell In[21], line 1
#     for idx, value in enumerate(collection):
#                                             ^
# SyntaxError: incomplete input

# %%
for idx, value in enumerate(collection):
    a.append((idx,value))

# %%
a
# Out:
# [(0, 1), (1, 2), (2, 3)]

# %%
seq1 = ["foo", "bar", "zara"]
seq2 = ["one", "two", "three"]

# %%
zipped = zip(seq1,seq2)

# %%
zipped

# %%
list(zipped)
# Out:
# [('foo', 'one'), ('bar', 'two'), ('zara', 'three')]

# %%
for index, (a,b) in enumerate(zip(seq1,seq2)):
    print(f"{index} : {a},{b}")
# Out:
# 0 : foo,one
# 1 : bar,two
# 2 : zara,three

# %%
strings = ["a", "as", "bat", "zara", "python"]

# %%
loc_mapping = {index : value for index, value in enumerate(strings)}

# %%
loc_mapping
# Out:
# {0: 'a', 1: 'as', 2: 'bat', 3: 'zara', 4: 'python'}

# %%
loc_mapping[0]
# Out:
# 'a'

# %%
loc_mapping['a']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 loc_mapping['a']
#
# KeyError: 'a'

# %%
def apply_to_list(some_list,f):
    return [f(x) for x in some_list]

# %%
ints = [4, 0, 1, 5, 6]

# %%
[x * 2 for x in ints]
# Out:
# [8, 0, 2, 10, 12]

# %%
apply_to_list(ints, lamda x : x * 2)
# Out:
#   Cell In[37], line 1
#     apply_to_list(ints, lamda x : x * 2)
#                         ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
apply_to_list(ints, lambda x : x * 2)
# Out:
# [8, 0, 2, 10, 12]

# %%
strings = ["foo", "card", "bar", "abab", "aaaa"]

# %%
strings.sort(key = lambda x : len(set(x)))

# %%
strings
# Out:
# ['aaaa', 'foo', 'abab', 'bar', 'card']
