# %%
import numpy as np

# %%
import pandas as pd

# %%
from pandas import Series, DataFrame

# %%
obj = Series([4,7,5,3])

# %%
obj
# Out:
# 0    4
# 1    7
# 2    5
# 3    3
# dtype: int64

# %%
obj.array
# Out:
# <NumpyExtensionArray>
# [4, 7, 5, 3]
# Length: 4, dtype: int64

# %%
obj2 = Series([4,7,5,3], index = ["d", "b", "a", "c"])

# %%
obj2
# Out:
# d    4
# b    7
# a    5
# c    3
# dtype: int64

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj2.index
# Out:
# Index(['d', 'b', 'a', 'c'], dtype='object')

# %%
obj2["a"]
# Out:
# np.int64(5)

# %%
obj2 > 0
# Out:
# d    True
# b    True
# a    True
# c    True
# dtype: bool

# %%
sdata = {"Ohio" : 35000, "Texas" : 71000, "Oregon" : 16000, "Utah" : 5000}

# %%
obj3 = Series(sdata)

# %%
sdata
# Out:
# {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}

# %%
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
obj3.to_dict()
# Out:
# {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}

# %%
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
states = ["California", "Ohio", "Oregon", "Texas"]

# %%
obj4 = Series(sdata, index = states)

# %%
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
pd.isna(obj4)
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
pd.notna(obj4)
# Out:
# California    False
# Ohio           True
# Oregon         True
# Texas          True
# dtype: bool

# %%
obj4.isna()
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
obj4.notna()
# Out:
# California    False
# Ohio           True
# Oregon         True
# Texas          True
# dtype: bool

# %%
obj4.name = "population"

# %%
obj4.index.name = "state"

# %%
obj4
# Out:
# state
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# Name: population, dtype: float64

# %%
obj
# Out:
# 0    4
# 1    7
# 2    5
# 3    3
# dtype: int64

# %%
obj[2] = -5

# %%
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
data = {"state": ["Ohio", "Ohio", "Ohio", "Nevada", "Nevada", "Nevada"],
        "year": [2000, 2001, 2002, 2001, 2002, 2003],
        "pop": [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
frame = pd.DataFrame(data)

# %%
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
frame.head()
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
frame.tail()
# Out:
#     state  year  pop
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
DataFrame(data, columns=["year","state","pop"])
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9
# 5  2003  Nevada  3.2

# %%
frame.loc[1]
# Out:
# state    Ohio
# year     2001
# pop       1.7
# Name: 1, dtype: object

# %%
pdata = {"Ohio": frame3["Ohio"][:-1],
         "Nevada": frame3["Nevada"][:2]}
pd.DataFrame(pdata)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 pdata = {"Ohio": frame3["Ohio"][:-1],
#       2          "Nevada": frame3["Nevada"][:2]}
#       3 pd.DataFrame(pdata)
#
# NameError: name 'frame3' is not defined

# %%
populations = {"Ohio": {2000: 1.5, 2001: 1.7, 2002: 3.6},
               "Nevada": {2001: 2.4, 2002: 2.9}}

# %%
frame2 = DataFrame(populations)

# %%
frame2
# Out:
#       Ohio  Nevada
# 2000   1.5     NaN
# 2001   1.7     2.4
# 2002   3.6     2.9

# %%
frame3.T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 frame3.T
#
# NameError: name 'frame3' is not defined

# %%
frame2.T
# Out:
#         2000  2001  2002
# Ohio     1.5   1.7   3.6
# Nevada   NaN   2.4   2.9

# %%
DataFrame(populations, index=[2001,2002,2003])
# Out:
#       Ohio  Nevada
# 2001   1.7     2.4
# 2002   3.6     2.9
# 2003   NaN     NaN

# %%
frame1.to_numpy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 frame1.to_numpy()
#
# NameError: name 'frame1' is not defined

# %%
frame.to_numpy()
# Out:
# array([['Ohio', 2000, 1.5],
#        ['Ohio', 2001, 1.7],
#        ['Ohio', 2002, 3.6],
#        ['Nevada', 2001, 2.4],
#        ['Nevada', 2002, 2.9],
#        ['Nevada', 2003, 3.2]], dtype=object)

# %%
frame2.to_numpy()
# Out:
# array([[1.5, nan],
#        [1.7, 2.4],
#        [3.6, 2.9]])

# %%
obj = Series(np.arange(3), index=["a", "b", "c"])

# %%
index = obj.index

# %%
index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
index[1:]
# Out:
# Index(['b', 'c'], dtype='object')

# %%
labels = pd.Index(np.arange(3))

# %%
labels
# Out:
# Index([0, 1, 2], dtype='int64')

# %%
obj2 = Series([1.5, -2.5, 0], index = labels)

# %%
obj2
# Out:
# 0    1.5
# 1   -2.5
# 2    0.0
# dtype: float64

# %%
obj.index is labels
# Out:
# False

# %%
obj2.index is labels
# Out:
# True

# %%
frame3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 frame3
#
# NameError: name 'frame3' is not defined

# %%
frame2
# Out:
#       Ohio  Nevada
# 2000   1.5     NaN
# 2001   1.7     2.4
# 2002   3.6     2.9

# %%
frame2.columns
# Out:
# Index(['Ohio', 'Nevada'], dtype='object', name='state')

# %%
frame2.columns.name = "state"

# %%
"Ohio" in frame2.columns
# Out:
# True

# %%
frame2.index
# Out:
# Index([2000, 2001, 2002], dtype='int64')

# %%
pd.Index(["foo","foo","bar","bar"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 pd.Index(["foo","foo","bar","bar"])
#
# TypeError: 'list' object is not callable

# %%
list = np.arange(3)

# %%
list
# Out:
# array([0, 1, 2])

# %%
pd.Index([0,1,2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 pd.Index([0,1,2])
#
# TypeError: 'list' object is not callable

# %%
pd.Index(np.array([0,1,2]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 pd.Index(np.array([0,1,2]))
#
# TypeError: 'list' object is not callable

# %%
np.array([0,1,2])
# Out:
# array([0, 1, 2])

# %%
idx = pd.Index(list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 idx = pd.Index(list)
#
# TypeError: 'list' object is not callable

# %%
del list

# %%
arr = np.arange(3)

# %%
arr
# Out:
# array([0, 1, 2])

# %%
idx = pd.Index(arr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 idx = pd.Index(arr)
#
# TypeError: 'list' object is not callable

# %%
print(type(list))
# Out:
# <class 'type'>

# %%
print(type(pd.Index)) 
# 만약 결과가 <class 'list'> 라면, pd.Index가 변수로 오염된 것입니다.
# 정상이라면 <class 'type'> (또는 pandas 내부 클래스명)이 떠야 합니다.
# Out:
# <class 'list'>

# %%
labels = pd.Index(["foo", "foo", "bar", "bar"])

# %%
labels
# Out:
# Index(['foo', 'foo', 'bar', 'bar'], dtype='object')

# %%
labels = labels.append(labels2)

# %%
labels2 = pd.Index(["tic", "tic"])

# %%
labels
# Out:
# Index(['foo', 'foo', 'bar', 'bar'], dtype='object')

# %%
labels
# Out:
# Index(['foo', 'foo', 'bar', 'bar', 'tic', 'tic'], dtype='object')

# %%
labels.difference(labels2)
# Out:
# Index(['bar', 'foo'], dtype='object')

# %%
labels.unique()
# Out:
# Index(['foo', 'bar', 'tic'], dtype='object')
